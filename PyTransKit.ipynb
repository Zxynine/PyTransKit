# %% [markdown]
# # Metainfo

# %% [markdown]
# ## What is the type of paper
#
# JOSS publishes articles about research software. This definition includes software that: solves complex modeling problems in a scientific context (physics, mathematics, biology, medicine, social science, neuroscience, engineering); supports the functioning of research instruments or the execution of research experiments; extracts knowledge from large data sets; offers a mathematical library, or similar.
#
# JOSS publishes articles about software that demonstrates clear research impact or credible scholarly significance. Your software should represent a meaningful contribution to the research community rather than being a one-off tool for a single analysis. Whether or not you use AI assistance in your development, submissions should demonstrate the irreplaceable human contributions: problem framing, key design decisions, thoughtful architectural choices, and practices that make software usable and sustainable for others.
#
# https://joss.readthedocs.io/en/latest/submitting.html

# %% [markdown]
# ## Key topics to cover
#
# Research impact: Evidence of publications or analyses using the software, external adopters or integrations, or credible near-term significance demonstrated through comparative benchmarks and reproducible reference materials. (Kris tracking downloads)
#
# Design thinking: Meaningful architectural decisions and trade-offs considered. We particularly work that builds upon or extends existing software ecosystems rather than reinventing solutions where quality alternatives already exist. (Auto diff through JAX)
#
# (Possible improvements in accuracy?)
#
# Open development practices: Sustained development over time with evidence of collaborative effort, public development history, comprehensive testing, clear documentation, and pathways for community contribution.
#
# How easy is the design to install/use/navigate/understand. Why it is better than alternatives. (Not OT package. Signal representation using OT)

# %% [markdown]
# # High-level outline
# (About one page each)
#
# 1. Abstract/Summary
# 2. Problem statement / Statement of need
# 3. Organisation of design
# 4. Dataflow / API / Functionality
# 5. Research Impact / Applications

# %% [markdown]
# ## 1) Abstract
# (Cover the overarching purpose of the toolkit enough to inform a reader on what ptk does and why it is useful)

# %% [markdown]
# ## 2) Problem Statement
# (Cover the specific problems this package hopes to solve and why there is a need for these problems to be solved)

# %% [markdown]
# Copied from github:
#
# Python Transport Based Signal Processing Toolkit
#
# Website and documentation: https://pytranskit.readthedocs.io/
#
# Introduction video
#
# This python package provides signal/image representation software methods (i.e. mathematical transforms) based on the idea of matching signals & images to a reference by pixel displacement operations that are physically related to the concept of transport phenomena. You can think of and use the transforms described below just as one would with the Fourier or Wavelet Transforms. By solving signal/image analysis in transport transform (e.g. Wasserstein embedding) space, one can dramatically simplify and linearize statistical regression problems, enabling the straight forward (e.g. closed form) solution of signal/image detection, estimation, and classification problems with increased accuracy using few training samples, with mathematical understanding and interpretability, better generalization properties, and computationally efficiently.

# %% [markdown]
# ## 3) Design Organisation
# (Cover how the overall package is structured and design decisions/choices to inform why the design is as such)

# %% [markdown]
# * PyTransKit (ROOT)
#     * docs blah blah
#     * pytranskit
#         * Frontend (User facing, object oriented)
#         * Backend  (Dev facing, functional oriented)

# %% [markdown]
# ```
#
# PyTransKit-rework/
# ├── .github/                  # Workflows for CI/CD automation
# │   └── workflows/
# ├── docs/                     # Documentation source files
# ├── src/                      # Source code directory (Highly recommended)
# │   └── pytranskit/           # Core package folder
# │       ├── __init__.py
# │       ├── frontend/
# │       |   └── ...
# │       └── backend/
# │           └── ...
# ├── tests/                    # Dedicated test directory (separate from source)
# │   ├── __init__.py
# │   └── test_core.py
# ├── examples/                 # Kept lowercase for consistency
# ├── .gitattributes
# ├── .gitignore
# ├── LICENSE
# ├── pyproject.toml            # Modern replacement for setup.py/setup.cfg
# ├── README.md
# └── requirements.txt
# ```

# %% [markdown]
# ### Pytranskit layout
#
# Frontend will be for the code that we intend for the users to utilize. This is an object-oriented style codebase that acts as wrappers for the backend code, allowing mutability and decoupling. This section is statefull and is all about keeping the functional backend "Pure" and stateless.
# * Frontend
#     * Transforms
#         * Distribution Transforms
#             - CDT, SCDT, RCDT
#         * Linear Optimal Transport Transforms
#             - CLOT, PLOT
#     * Classifiers
#         * [TYPES OF CLASSIFIERS]
#     * Estimators
#         * [TYPES OF ESTIMATORS]
#
# The Backend is where the actual code lies. This code dictates the underlying functionality of the entire codebase.
# * Backend
#     * Transform Engines (Or transformers or transform functionals)
#         - See Frontend Transforms... ^^^
#     * Classifier Engines
#         - Generic modular classifiers
#     * Estimator Engines
#         - Generic modular estimators
#
#
#
# The Application-end is where internal utilities exist for the code used in examples/tutorials
# * Modeling
# *

# %% [markdown]
# ## 4) Dataflow / API / Functionality
# (Cover total functionality of the package and how data flows in various scenarios)

# %% [markdown]
# ## 5) Research Impact / Applications
# (Cover the ways this package impacts research and how it can be applied therein)
